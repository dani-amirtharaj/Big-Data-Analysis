# %%
import requests
import argparse
import time
import json
import gzip
import csv
import codecs
from io import StringIO
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.stem import WordNetLemmatizer 
import nltk
import re
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Dan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def search_domain(domain):
    record_list = []
    print ("[*] Trying target domain: %s" % domain)
    cc_url  = "http://index.commoncrawl.org/CC-MAIN-%s-index?" % "2019-13"
    cc_url += "url=%s&matchType=prefix&output=json&filter=status:200&limit=1000" % domain
    response = requests.get(cc_url)
    if response.status_code == 200:
        records = response.content.splitlines()
        for record in records:
            record_list.append(json.loads(record))
        print ("[*] Added %d results." % len(records))
    print ("[*] Found a total of %d hits." % len(record_list))
    return record_list

# %%
def download_page(record, genre):
    offset, length = int(record['offset']), int(record['length'])
    offset_end = offset + length - 1
    prefix = 'https://commoncrawl.s3.amazonaws.com/'
    resp = requests.get(prefix + record['filename'], headers={'Range': 'bytes={}-{}'.format(offset, offset_end)})
    raw_data = gzip.decompress(resp.content)
    data = raw_data.decode()   
    content = ""
    if len(data):
        try:
            warc, header, response = data.strip().split('\r\n\r\n', 2)
            doc = BeautifulSoup(response , 'lxml')
            if genre in ("music", "country"):
                content = doc.find('meta', {"name" : "body"})['content']
                if ("<" in content):
                    content = ""
            elif genre in "jazz":
                content = " ".join([asd.getText() for asd in doc.find_all('p')[:-4]])
            elif genre in "rap":
                content = " ".join([asd.getText() for asd in doc.find_all('p')[2:-2]])
            elif genre in "rock":
                content = " ".join([asd.getText() for asd in doc.find_all('p')[:]])
            elif genre in "classical":
                content = re.sub(".*?\n\n\n", "", re.sub("See more Latest features.*", "", " ".join([asd.getText() for asd in doc.find_all('p')])), flags=re.DOTALL)
#                 content = re.sub("Additional notes.*", "",  content)
            elif genre in "pop":
                content = " ".join([asd.getText() for asd in doc.find_all('p')[:-4]])
            else:
                content = response
        except:
            pass   
    return  content

# %%
domainPrefix = [["rollingstone.com/music/", "music"], ["jazztimes.com/", "jazz"], ["allhiphop.com", "rap"], ["rollingstone.com/music/music-country/", "country"], ["loudwire.com", "rock"], ["popjustice.com/", "pop"], ["classicfm.com/discover-music/", "classical"] ]
for domain, genre  in domainPrefix:
    cnt = 0
    extractedText = []
    urlList = []
    pageList = []
    pages = search_domain(domain)
    for page in pages:
        if (cnt == 200):
            break
        downloadedPage = download_page(page, genre)
        if (len(re.sub("\s", "", downloadedPage)) > 0 and page['url'] not in urlList and downloadedPage not in pageList):
            extractedText.append([domain, genre, page['url'], downloadedPage, page['filename']])
            urlList.append(page['url'])
            pageList.append(downloadedPage)
            cnt+=1
    if (extractedText):
        pd.DataFrame(extractedText).to_csv("Extracted Raw Articles/Raw_Articles_"+genre+".csv", header=["Domain/Prefix", "Genre", "URL", "Text", "Warc file"])
# Out:
# [*] Trying target domain: rollingstone.com/music/
# [*] Added 1000 results.
# [*] Found a total of 1000 hits.
# [*] Trying target domain: jazztimes.com/
# [*] Added 1000 results.
# [*] Found a total of 1000 hits.
# [*] Trying target domain: allhiphop.com
# [*] Added 1000 results.
# [*] Found a total of 1000 hits.
# [*] Trying target domain: rollingstone.com/music/music-country/
# [*] Added 1000 results.
# [*] Found a total of 1000 hits.
# [*] Trying target domain: loudwire.com
# [*] Added 1000 results.
# [*] Found a total of 1000 hits.
# [*] Trying target domain: popjustice.com/
# [*] Added 807 results.
# [*] Found a total of 807 hits.
# [*] Trying target domain: classicfm.com/discover-music/
# [*] Added 1000 results.
# [*] Found a total of 1000 hits.

# %%
domainPrefix = [["rollingstone.com/music/", "music"], ["jazztimes.com/", "jazz"], ["allhiphop.com", "rap"], ["rollingstone.com/music/music-country/", "country"], ["loudwire.com", "rock"], ["popjustice.com/", "pop"], ["classicfm.com/discover-music/", "classical"] ]
ccDFs = []
for domain, genre in domainPrefix:
    ccDFs.append(pd.read_csv("Extracted Raw Articles/Raw_Articles_"+genre+".csv"))

# %%
ccDFs[0]
# Out:
#      Unnamed: 0            Domain/Prefix  Genre  \
# 0             0  rollingstone.com/music/  music
# 1             1  rollingstone.com/music/  music
# 2             2  rollingstone.com/music/  music
# 3             3  rollingstone.com/music/  music
# 4             4  rollingstone.com/music/  music
# 5             5  rollingstone.com/music/  music
# 6             6  rollingstone.com/music/  music
# 7             7  rollingstone.com/music/  music
# 8             8  rollingstone.com/music/  music
# 9             9  rollingstone.com/music/  music
# 10           10  rollingstone.com/music/  music
# 11           11  rollingstone.com/music/  music
# 12           12  rollingstone.com/music/  music
# 13           13  rollingstone.com/music/  music
# 14           14  rollingstone.com/music/  music
# 15           15  rollingstone.com/music/  music
# 16           16  rollingstone.com/music/  music
# 17           17  rollingstone.com/music/  music
# 18           18  rollingstone.com/music/  music
# 19           19  rollingstone.com/music/  music
# 20           20  rollingstone.com/music/  music
# 21           21  rollingstone.com/music/  music
# 22           22  rollingstone.com/music/  music
# 23           23  rollingstone.com/music/  music
# 24           24  rollingstone.com/music/  music
# 25           25  rollingstone.com/music/  music
# 26           26  rollingstone.com/music/  music
# 27           27  rollingstone.com/music/  music
# 28           28  rollingstone.com/music/  music
# 29           29  rollingstone.com/music/  music
# ..          ...                      ...    ...
# 170         170  rollingstone.com/music/  music
# 171         171  rollingstone.com/music/  music
# 172         172  rollingstone.com/music/  music
# 173         173  rollingstone.com/music/  music
# 174         174  rollingstone.com/music/  music
# 175         175  rollingstone.com/music/  music
# 176         176  rollingstone.com/music/  music
# 177         177  rollingstone.com/music/  music
# 178         178  rollingstone.com/music/  music
# 179         179  rollingstone.com/music/  music
# 180         180  rollingstone.com/music/  music
# 181         181  rollingstone.com/music/  music
# 182         182  rollingstone.com/music/  music
# 183         183  rollingstone.com/music/  music
# 184         184  rollingstone.com/music/  music
# 185         185  rollingstone.com/music/  music
# 186         186  rollingstone.com/music/  music
# 187         187  rollingstone.com/music/  music
# 188         188  rollingstone.com/music/  music
# 189         189  rollingstone.com/music/  music
# 190         190  rollingstone.com/music/  music
# 191         191  rollingstone.com/music/  music
# 190  A somewhat unnecessary greatest-hits for the S...
# 191  Concerning Alice Cooper, it is by now axiomati...
# 192  Phish&apos;s last album, the double CD A Live ...
# 193  At his best Chuck Berry was a hip short-story ...
# 194  Bjork sings it like a sorceress sharing a reci...
# 195  Miles&apos; music continues to grow in its bea...
# 196  Although the Rolling Stones now sing about the...
# 197  Routinely dismissed as a band of synth-pop rob...
# 198  In the world according to AC/DC, sex, money, p...
# 199  Don&apos;t ask me what&apos;s happened to Mart...
#
#                                              Warc file
# 0    crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 1    crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 2    crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 3    crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 4    crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 5    crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 6    crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 7    crawl-data/CC-MAIN-2019-13/segments/1552912205...
# 8    crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 9    crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 10   crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 11   crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 12   crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 13   crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 14   crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 15   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 16   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 17   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 18   crawl-data/CC-MAIN-2019-13/segments/1552912204...
# 19   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 20   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 21   crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 22   crawl-data/CC-MAIN-2019-13/segments/1552912205...
# 23   crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 24   crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 25   crawl-data/CC-MAIN-2019-13/segments/1552912205...
# 26   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 27   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 28   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 29   crawl-data/CC-MAIN-2019-13/segments/1552912202...
# ..                                                 ...
# 170  crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 171  crawl-data/CC-MAIN-2019-13/segments/1552912204...
# 172  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 173  crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 174  crawl-data/CC-MAIN-2019-13/segments/1552912207...
# 175  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 176  crawl-data/CC-MAIN-2019-13/segments/1552912204...
# 177  crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 178  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 179  crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 180  crawl-data/CC-MAIN-2019-13/segments/1552912203...
# 181  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 182  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 183  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 184  crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 185  crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 186  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 187  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 188  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 189  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 190  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 191  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 192  crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 193  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 194  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 195  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 196  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 197  crawl-data/CC-MAIN-2019-13/segments/1552912202...
# 198  crawl-data/CC-MAIN-2019-13/segments/1552912201...
# 199  crawl-data/CC-MAIN-2019-13/segments/1552912203...
#
# [200 rows x 6 columns]

# %%
for ccDF in ccDFs:
    if (ccDF.shape[0] != ccDF['URL'].nunique()):
        print("Duplicate URLs found!")
print("No duplicate URLs found!")
print("Total number of unique URLs: ", pd.concat(ccDFs)['URL'].nunique())
# Out:
# No duplicate URLs found!
# Total number of unique URLs:  1400

# %%
stopWordsSet = set(stopwords.words('english')) 
stopWordsSet.update(("going","get","thing","also","really","would","know","say","way","got","lot","said","like","could","allhiphop","chuck","creekmur","he"))

for ccDF in ccDFs:
    keyword = ccDF["Genre"][0]
    with open("Pre-Processed Articles/commoncrawl_text_"+keyword+".txt", "a+") as text_file:
        for index, row in ccDF.iterrows():
            ccText = str.strip(re.sub('\s?https?://.*?[\s|\n]', '', row["Text"]+" "))
            ccText = re.sub('&.*?;', '', ccText)
            ccText = re.sub("[\n|\r]+", "\n", ccText)
            for text in ccText.split("\n"):
                text = " ".join(re.findall("[a-zA-Z]+",text))
                tokenizedText = word_tokenize(text.lower())
                finalText = " ".join([WordNetLemmatizer().lemmatize(w) for w in tokenizedText if not w in stopWordsSet and len(WordNetLemmatizer().lemmatize(w)) >= 3])
                text_file.write(str.strip(finalText) + "\n")
